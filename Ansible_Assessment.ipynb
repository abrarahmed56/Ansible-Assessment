# %% [markdown]
# <a href="https://colab.research.google.com/github/abrarahmed56/Ansible-Assessment/blob/main/Ansible_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from googleapiclient.discovery import build

# Build the Drive service
drive_service = build('drive', 'v3')

# Define the metadata for the new Google Docs document
file_metadata = {
    'name': 'Abrar Ahmed Ansible Assessment- Meeting Notes using Colab',
    'mimeType': 'application/vnd.google-apps.document'
}

file = drive_service.files().create(body=file_metadata, fields='id,webViewLink').execute()

print(f"Google Docs document created with ID: {file.get('id')}")
print(f"Access it at: {file.get('webViewLink')}")
# Out:
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# Google Docs document created with ID: 1Oc9KjsoAXzIMGzmj5djH664FzE_iTFQaM6C14Ovo760
# Access it at: https://docs.google.com/document/d/1Oc9KjsoAXzIMGzmj5djH664FzE_iTFQaM6C14Ovo760/edit?usp=drivesdk

# %%
notes = """# Product Team Sync - May 15, 2023

## Attendees
- Sarah Chen (Product Lead)
- Mike Johnson (Engineering)
- Anna Smith (Design)
- David Park (QA)

## Agenda

### 1. Sprint Review
* Completed Features
  * User authentication flow
  * Dashboard redesign
  * Performance optimization
    * Reduced load time by 40%
    * Implemented caching solution
* Pending Items
  * Mobile responsive fixes
  * Beta testing feedback integration

### 2. Current Challenges
* Resource constraints in QA team
* Third-party API integration delays
* User feedback on new UI
  * Navigation confusion
  * Color contrast issues

### 3. Next Sprint Planning
* Priority Features
  * Payment gateway integration
  * User profile enhancement
  * Analytics dashboard
* Technical Debt
  * Code refactoring
  * Documentation updates

## Action Items
- [ ] @sarah: Finalize Q3 roadmap by Friday
- [ ] @mike: Schedule technical review for payment integration
- [ ] @anna: Share updated design system documentation
- [ ] @david: Prepare QA resource allocation proposal

## Next Steps
* Schedule individual team reviews
* Update sprint board
* Share meeting summary with stakeholders

## Notes
* Next sync scheduled for May 22, 2023
* Platform demo for stakeholders on May 25
* Remember to update JIRA tickets

---
Meeting recorded by: Sarah Chen
Duration: 45 minutes
"""

# %%
formatted_lines = []

formatting_markers = [
    ("# ", "HEADING_1"),
    ("## ", "HEADING_2"),
    ("### ", "HEADING_3"),
    ("* ", "BULLET"),
    ("- [ ] ", "CHECKBOX"),
    ("- ", "DASH"),
]
# Any character between "@" and the below will be bolded
# For example, in "@Abrar:", bolding will end at the second "r"
tag_enders = [" ", ":", "&"]

bullet_spacing = []
bullet_sections = []
footer_started = False
last_paragraph_style = None

for line in notes.split("\n"):
  found_format = False
  for marker, style in formatting_markers:
    if line.strip().startswith(marker):
      stripped_line_text = line[line.find(marker)+len(marker):].strip()
      if style == "BULLET":
        current_bullet_spacing = line.find(marker)
        while bullet_spacing and bullet_spacing[-1] >= current_bullet_spacing:
          bullet_spacing.pop()
        bullet_tabs = "\t" * len(bullet_spacing)
        bullet_spacing.append(current_bullet_spacing)
        formatted_lines.append({
            "text": bullet_tabs + stripped_line_text + "\n",
            "paragraph_style": style
          })
      else:
        if bullet_spacing:
          bullet_spacing = []
        last_paragraph_style = style
        formatted_lines.append({
            "text": stripped_line_text + "\n",
            "paragraph_style": style
          })
      found_format = True
      break
  if not found_format:
    formatted_line = {"text": line.strip() + "\n"}
    if footer_started:
      formatted_line['text_style'] = 'ITALIC'
    if line.startswith("---"):
      footer_started = True
    formatted_lines.append(formatted_line)
    last_paragraph_style = None

# Remove newlines before and after headings
i = 0
while i < len(formatted_lines):
  if 'paragraph_style' in formatted_lines[i] and formatted_lines[i]['paragraph_style'].startswith('HEADING'):
    if i > 1 and formatted_lines[i-1] == {'text': '\n'}:
      formatted_lines.pop(i-1)
      i -= 1
    if i < len(formatted_lines) - 1 and formatted_lines[i+1] == {'text': '\n'}:
      formatted_lines.pop(i+1)
  i += 1

formatted_lines
# Out:
# [{'text': 'Product Team Sync - May 15, 2023\n',
#   'paragraph_style': 'HEADING_1'},
#  {'text': 'Attendees\n', 'paragraph_style': 'HEADING_2'},
#  {'text': 'Sarah Chen (Product Lead)\n', 'paragraph_style': 'DASH'},
#  {'text': 'Mike Johnson (Engineering)\n', 'paragraph_style': 'DASH'},
#  {'text': 'Anna Smith (Design)\n', 'paragraph_style': 'DASH'},
#  {'text': 'David Park (QA)\n', 'paragraph_style': 'DASH'},
#  {'text': 'Agenda\n', 'paragraph_style': 'HEADING_2'},
#  {'text': '1. Sprint Review\n', 'paragraph_style': 'HEADING_3'},
#  {'text': 'Completed Features\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tUser authentication flow\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tDashboard redesign\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tPerformance optimization\n', 'paragraph_style': 'BULLET'},
#  {'text': '\t\tReduced load time by 40%\n', 'paragraph_style': 'BULLET'},
#  {'text': '\t\tImplemented caching solution\n', 'paragraph_style': 'BULLET'},
#  {'text': 'Pending Items\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tMobile responsive fixes\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tBeta testing feedback integration\n',
#   'paragraph_style': 'BULLET'},
#  {'text': '2. Current Challenges\n', 'paragraph_style': 'HEADING_3'},
#  {'text': 'Resource constraints in QA team\n', 'paragraph_style': 'BULLET'},
#  {'text': 'Third-party API integration delays\n', 'paragraph_style': 'BULLET'},
#  {'text': 'User feedback on new UI\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tNavigation confusion\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tColor contrast issues\n', 'paragraph_style': 'BULLET'},
#  {'text': '3. Next Sprint Planning\n', 'paragraph_style': 'HEADING_3'},
#  {'text': 'Priority Features\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tPayment gateway integration\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tUser profile enhancement\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tAnalytics dashboard\n', 'paragraph_style': 'BULLET'},
#  {'text': 'Technical Debt\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tCode refactoring\n', 'paragraph_style': 'BULLET'},
#  {'text': '\tDocumentation updates\n', 'paragraph_style': 'BULLET'},
#  {'text': 'Action Items\n', 'paragraph_style': 'HEADING_2'},
#  {'text': '@sarah: Finalize Q3 roadmap by Friday\n',
#   'paragraph_style': 'CHECKBOX'},
#  {'text': '@mike: Schedule technical review for payment integration\n',
#   'paragraph_style': 'CHECKBOX'},
#  {'text': '@anna: Share updated design system documentation\n',
#   'paragraph_style': 'CHECKBOX'},
#  {'text': '@david: Prepare QA resource allocation proposal\n',
#   'paragraph_style': 'CHECKBOX'},
#  {'text': 'Next Steps\n', 'paragraph_style': 'HEADING_2'},
#  {'text': 'Schedule individual team reviews\n', 'paragraph_style': 'BULLET'},
#  {'text': 'Update sprint board\n', 'paragraph_style': 'BULLET'},
#  {'text': 'Share meeting summary with stakeholders\n',
#   'paragraph_style': 'BULLET'},
#  {'text': 'Notes\n', 'paragraph_style': 'HEADING_2'},
#  {'text': 'Next sync scheduled for May 22, 2023\n',
#   'paragraph_style': 'BULLET'},
#  {'text': 'Platform demo for stakeholders on May 25\n',
#   'paragraph_style': 'BULLET'},
#  {'text': 'Remember to update JIRA tickets\n', 'paragraph_style': 'BULLET'},
#  {'text': '\n'},
#  {'text': '---\n'},
#  {'text': 'Meeting recorded by: Sarah Chen\n', 'text_style': 'ITALIC'},
#  {'text': 'Duration: 45 minutes\n', 'text_style': 'ITALIC'},
#  {'text': '\n', 'text_style': 'ITALIC'}]

# %%
requests = []
cursor = 1
processing_bullets = False
bullet_style = 'BULLET_DISC_CIRCLE_SQUARE' # default bullet style
bullets_beginning = -1
tabs_to_replace = 0

for line in formatted_lines:
  requests.append({
      'insertText': {
          'location': {'index': cursor},
          'text': line['text'],
        },
    })
  if 'paragraph_style' in line:
    if line['paragraph_style'] == 'BULLET' or line['paragraph_style'] == 'DASH':
      if not processing_bullets:
        processing_bullets = True
        bullets_beginning = cursor
        if line['paragraph_style'] == 'BULLET':
          bullet_style = 'BULLET_DISC_CIRCLE_SQUARE'
        else:
          bullet_style = 'BULLET_ARROW_DIAMOND_DISC'
      tabs_to_replace += line['text'].count("\t")
    elif line['paragraph_style'] == 'CHECKBOX':
      requests.append({
          'createParagraphBullets': {
              'range': {
                  'startIndex': cursor,
                  'endIndex': cursor + len(line['text'])
              },
              'bulletPreset': 'BULLET_CHECKBOX',
          }
      })
    else:
      if processing_bullets:
        requests.append({
            'createParagraphBullets': {
                'range': {'startIndex': bullets_beginning, 'endIndex': cursor},
                'bulletPreset': bullet_style,
            },
        })
        cursor -= tabs_to_replace
        tabs_to_replace = 0
        processing_bullets = False
        bullet_style = 'BULLET_DISC_CIRCLE_SQUARE'
        bullets_beginning = -1
      requests.append({
          'updateParagraphStyle': {
              'paragraphStyle': { 'namedStyleType': line['paragraph_style'] },
              'range': {
                  'startIndex': cursor,
                  'endIndex': cursor + len(line['text']) - 1,
              },
              'fields': '*',
            },
      })
  else:
    if processing_bullets:
      requests.append({
          'createParagraphBullets': {
              'range': {'startIndex': bullets_beginning, 'endIndex': cursor},
              'bulletPreset': bullet_style,
          },
      })
      cursor -= tabs_to_replace
      tabs_to_replace = 0
      processing_bullets = False
      bullet_style = 'BULLET_DISC_CIRCLE_SQUARE'
      bullets_beginning = -1
    if 'text_style' in line:
      requests.append({
          'updateTextStyle': {
              'range': {
                  'startIndex': cursor,
                  'endIndex': cursor + len(line['text']),
              },
              'textStyle': {'italic': line['text_style'] == 'ITALIC'},
              'fields': '*',
          },
      })
  if "@" in line['text']:
    indices_to_bold = []
    start_index = 0
    while "@" in line['text'][start_index:]:
      start_index = line['text'].find("@", start_index)
      end_index = start_index + 1
      while end_index < len(line['text']) and line['text'][end_index] not in tag_enders:
        end_index += 1
      if end_index == -1:
        end_index = len(line['text'])
      indices_to_bold.append((start_index, end_index))
      start_index = end_index
    for start, end in indices_to_bold:
      requests.append({
          'updateTextStyle': {
              'range': {'startIndex': cursor + start, 'endIndex': cursor + end},
              'textStyle': {'bold': True},
              'fields': '*'
          }
      })
  cursor += len(line['text'])

requests
# Out:
# [{'insertText': {'location': {'index': 1},
#    'text': 'Product Team Sync - May 15, 2023\n'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_1'},
#    'range': {'startIndex': 1, 'endIndex': 33},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 34}, 'text': 'Attendees\n'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_2'},
#    'range': {'startIndex': 34, 'endIndex': 43},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 44},
#    'text': 'Sarah Chen (Product Lead)\n'}},
#  {'insertText': {'location': {'index': 70},
#    'text': 'Mike Johnson (Engineering)\n'}},
#  {'insertText': {'location': {'index': 97}, 'text': 'Anna Smith (Design)\n'}},
#  {'insertText': {'location': {'index': 117}, 'text': 'David Park (QA)\n'}},
#  {'insertText': {'location': {'index': 133}, 'text': 'Agenda\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 44, 'endIndex': 133},
#    'bulletPreset': 'BULLET_ARROW_DIAMOND_DISC'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_2'},
#    'range': {'startIndex': 133, 'endIndex': 139},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 140}, 'text': '1. Sprint Review\n'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_3'},
#    'range': {'startIndex': 140, 'endIndex': 156},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 157}, 'text': 'Completed Features\n'}},
#  {'insertText': {'location': {'index': 176},
#    'text': '\tUser authentication flow\n'}},
#  {'insertText': {'location': {'index': 202},
#    'text': '\tDashboard redesign\n'}},
#  {'insertText': {'location': {'index': 222},
#    'text': '\tPerformance optimization\n'}},
#  {'insertText': {'location': {'index': 248},
#    'text': '\t\tReduced load time by 40%\n'}},
#  {'insertText': {'location': {'index': 275},
#    'text': '\t\tImplemented caching solution\n'}},
#  {'insertText': {'location': {'index': 306}, 'text': 'Pending Items\n'}},
#  {'insertText': {'location': {'index': 320},
#    'text': '\tMobile responsive fixes\n'}},
#  {'insertText': {'location': {'index': 345},
#    'text': '\tBeta testing feedback integration\n'}},
#  {'insertText': {'location': {'index': 380},
#    'text': '2. Current Challenges\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 157, 'endIndex': 380},
#    'bulletPreset': 'BULLET_DISC_CIRCLE_SQUARE'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_3'},
#    'range': {'startIndex': 371, 'endIndex': 392},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 393},
#    'text': 'Resource constraints in QA team\n'}},
#  {'insertText': {'location': {'index': 425},
#    'text': 'Third-party API integration delays\n'}},
#  {'insertText': {'location': {'index': 460},
#    'text': 'User feedback on new UI\n'}},
#  {'insertText': {'location': {'index': 484},
#    'text': '\tNavigation confusion\n'}},
#  {'insertText': {'location': {'index': 506},
#    'text': '\tColor contrast issues\n'}},
#  {'insertText': {'location': {'index': 529},
#    'text': '3. Next Sprint Planning\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 393, 'endIndex': 529},
#    'bulletPreset': 'BULLET_DISC_CIRCLE_SQUARE'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_3'},
#    'range': {'startIndex': 527, 'endIndex': 550},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 551}, 'text': 'Priority Features\n'}},
#  {'insertText': {'location': {'index': 569},
#    'text': '\tPayment gateway integration\n'}},
#  {'insertText': {'location': {'index': 598},
#    'text': '\tUser profile enhancement\n'}},
#  {'insertText': {'location': {'index': 624},
#    'text': '\tAnalytics dashboard\n'}},
#  {'insertText': {'location': {'index': 645}, 'text': 'Technical Debt\n'}},
#  {'insertText': {'location': {'index': 660}, 'text': '\tCode refactoring\n'}},
#  {'insertText': {'location': {'index': 678},
#    'text': '\tDocumentation updates\n'}},
#  {'insertText': {'location': {'index': 701}, 'text': 'Action Items\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 551, 'endIndex': 701},
#    'bulletPreset': 'BULLET_DISC_CIRCLE_SQUARE'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_2'},
#    'range': {'startIndex': 696, 'endIndex': 708},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 709},
#    'text': '@sarah: Finalize Q3 roadmap by Friday\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 709, 'endIndex': 747},
#    'bulletPreset': 'BULLET_CHECKBOX'}},
#  {'updateTextStyle': {'range': {'startIndex': 709, 'endIndex': 715},
#    'textStyle': {'bold': True},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 747},
#    'text': '@mike: Schedule technical review for payment integration\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 747, 'endIndex': 804},
#    'bulletPreset': 'BULLET_CHECKBOX'}},
#  {'updateTextStyle': {'range': {'startIndex': 747, 'endIndex': 752},
#    'textStyle': {'bold': True},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 804},
#    'text': '@anna: Share updated design system documentation\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 804, 'endIndex': 853},
#    'bulletPreset': 'BULLET_CHECKBOX'}},
#  {'updateTextStyle': {'range': {'startIndex': 804, 'endIndex': 809},
#    'textStyle': {'bold': True},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 853},
#    'text': '@david: Prepare QA resource allocation proposal\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 853, 'endIndex': 901},
#    'bulletPreset': 'BULLET_CHECKBOX'}},
#  {'updateTextStyle': {'range': {'startIndex': 853, 'endIndex': 859},
#    'textStyle': {'bold': True},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 901}, 'text': 'Next Steps\n'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_2'},
#    'range': {'startIndex': 901, 'endIndex': 911},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 912},
#    'text': 'Schedule individual team reviews\n'}},
#  {'insertText': {'location': {'index': 945}, 'text': 'Update sprint board\n'}},
#  {'insertText': {'location': {'index': 965},
#    'text': 'Share meeting summary with stakeholders\n'}},
#  {'insertText': {'location': {'index': 1005}, 'text': 'Notes\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 912, 'endIndex': 1005},
#    'bulletPreset': 'BULLET_DISC_CIRCLE_SQUARE'}},
#  {'updateParagraphStyle': {'paragraphStyle': {'namedStyleType': 'HEADING_2'},
#    'range': {'startIndex': 1005, 'endIndex': 1010},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 1011},
#    'text': 'Next sync scheduled for May 22, 2023\n'}},
#  {'insertText': {'location': {'index': 1048},
#    'text': 'Platform demo for stakeholders on May 25\n'}},
#  {'insertText': {'location': {'index': 1089},
#    'text': 'Remember to update JIRA tickets\n'}},
#  {'insertText': {'location': {'index': 1121}, 'text': '\n'}},
#  {'createParagraphBullets': {'range': {'startIndex': 1011, 'endIndex': 1121},
#    'bulletPreset': 'BULLET_DISC_CIRCLE_SQUARE'}},
#  {'insertText': {'location': {'index': 1122}, 'text': '---\n'}},
#  {'insertText': {'location': {'index': 1126},
#    'text': 'Meeting recorded by: Sarah Chen\n'}},
#  {'updateTextStyle': {'range': {'startIndex': 1126, 'endIndex': 1158},
#    'textStyle': {'italic': True},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 1158},
#    'text': 'Duration: 45 minutes\n'}},
#  {'updateTextStyle': {'range': {'startIndex': 1158, 'endIndex': 1179},
#    'textStyle': {'italic': True},
#    'fields': '*'}},
#  {'insertText': {'location': {'index': 1179}, 'text': '\n'}},
#  {'updateTextStyle': {'range': {'startIndex': 1179, 'endIndex': 1180},
#    'textStyle': {'italic': True},
#    'fields': '*'}}]

# %%
docs_service = build('docs', 'v1')
try:
  result = docs_service.documents().batchUpdate(
    documentId=file.get('id'),
    body={'requests': requests}
  ).execute()
  print("Batch update successful!")
except Exception as e:
  print("Batch update failed, make sure notes were parsed correctly and "
        "requests are well-formed")
  print(e)
# Out:
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# WARNING:google_auth_httplib2:httplib2 transport does not support per-request timeout. Set the timeout when constructing the httplib2.Http instance.
# Batch update successful!
